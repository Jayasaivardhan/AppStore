# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayasaivardhan/AppStore/blob/main/StockPriceAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit langchain openai python-dotenv faiss-cpu pyngrok unstructured
# !pip install langchain-community
# !pip install langchain-openai

# %%
# !wget -q -O - https://ipv4.icanhazip.com
# Out:
# 34.56.6.155

# %%
# !streamlit run /content/Stock_Price_Analysis./app.py --server.port 8503 & npx localtunnel --port 8503
# Out:
# ...
#
# ⠙⠹⠸⠼
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8503
#   Network URL: http://172.28.0.12:8503
#   External URL: http://34.56.6.155:8503
#
# ⠴⠦your url is: https://tall-nights-turn.loca.lt
# /usr/local/lib/python3.10/dist-packages/langchain/__init__.py:30: UserWarning: Importing OpenAI from langchain root module is no longer supported. Please use langchain_community.llms.OpenAI instead.
#   warnings.warn(
# /content/Stock_Price_Analysis./app.py:27: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm = OpenAI(temperature=0.9, max_tokens=500)  # Initializing OpenAI language model
# ...
